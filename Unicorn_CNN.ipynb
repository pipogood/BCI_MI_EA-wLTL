# %% [markdown]
# # EEG-Unicorn preprocess and classification
#
# /*Using architechture from https://www.sciencedirect.com/science/article/pii/S156849461830663X?casa_token=KLEwDd7vsNIAAAAA:fkmAEsunSIAuBUiAuliENQiG-7o-O-6GaUBGye3UqErwrCwHj-daeyaXQUPiNKk_Vkxwvw /*

# %%
import mne
import numpy as np
from mne.datasets import eegbci
import matplotlib.pyplot as plt
from os import listdir
from mne.channels import make_standard_montage
from BCIAllFunction import BCIFuntions

# ['Fz','C3', 'Cz','C4','Pz','PO7','Oz','PO8']

AllBCIClass = BCIFuntions(numclass = 4, frequency = 250, ch_pick = ['Fz','C3', 'Cz','C4','Pz'])

all_data = ["pipo","NutF8","AJpang","Aoomim","voen","pipo_HCI","Kawin"]

target_data = "Aoomim"
SEED = 42
test_size = 0.3

EEG_data = AllBCIClass.GetRawEDF(target_subjects= all_data, condition="offline") #Input data -> 250Hz with 6-32 Hz filtered + CAR
# Out:
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo\notch_EDF\sess1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo\notch_EDF\sess2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo\notch_EDF\sess3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\NutF8\notch_EDF\sess1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\NutF8\notch_EDF\sess2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\NutF8\notch_EDF\sess3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\AJpang\notch_EDF\sess1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\AJpang\notch_EDF\sess2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\AJpang\notch_EDF\sess3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\Aoomim\notch_EDF\sess1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\Aoomim\notch_EDF\sess2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\Aoomim\notch_EDF\sess3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\voen\notch_EDF\sess1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\voen\notch_EDF\sess2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\voen\notch_EDF\sess3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo_HCI\notch_EDF\sess1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo_HCI\notch_EDF\sess2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo_HCI\notch_EDF\sess3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo_HCI\notch_EDF\sess4.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo_HCI\notch_EDF\sess5.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\pipo_HCI\notch_EDF\sess6.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\Kawin\notch_EDF\sess1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\Kawin\notch_EDF\sess2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\git\Senior_Thesis\DataSet\Offline_Experiment\Kawin\notch_EDF\sess3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Successful to create Data of ['pipo', 'NutF8', 'AJpang', 'Aoomim', 'voen', 'pipo_HCI', 'Kawin']

# %%
EEG_Epochs = AllBCIClass.GetEpoch(EEG_data ,tmin= -2.0, tmax= 6.0, crop = (0,4) ,baseline= (-1.0,0.0), trial_removal_th = 100)
# Out:
# Used Annotations descriptions: ['OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_Left', 'OVTK_GDF_Right', 'OVTK_GDF_Tongue', 'OVTK_GDF_Up']
# Used Annotations descriptions: ['OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_Left', 'OVTK_GDF_Right', 'OVTK_GDF_Tongue', 'OVTK_GDF_Up']
# NutF8 -106.25766567726194 6
# NutF8 88.12834464719897 6
# NutF8 -107.08932829116885 11
# NutF8 95.81900272747419 11
# Used Annotations descriptions: ['OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_Left', 'OVTK_GDF_Right', 'OVTK_GDF_Tongue', 'OVTK_GDF_Up']
# c:\git\BCI_MI_Study\BCIAllFunction.py:92: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   train_data = EEG_epoch[key_subs]['Raw_Epoch'].get_data()
# c:\git\BCI_MI_Study\BCIAllFunction.py:92: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   train_data = EEG_epoch[key_subs]['Raw_Epoch'].get_data()
# Used Annotations descriptions: ['OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_Left', 'OVTK_GDF_Right', 'OVTK_GDF_Tongue', 'OVTK_GDF_Up']
# Used Annotations descriptions: ['OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_Left', 'OVTK_GDF_Right', 'OVTK_GDF_Tongue', 'OVTK_GDF_Up']
# c:\git\BCI_MI_Study\BCIAllFunction.py:92: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   train_data = EEG_epoch[key_subs]['Raw_Epoch'].get_data()
# c:\git\BCI_MI_Study\BCIAllFunction.py:92: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   train_data = EEG_epoch[key_subs]['Raw_Epoch'].get_data()
# voen -1041.6969984917885 1
# voen 775.2039290736344 1
# voen -1107.9198488701486 2
# voen 1035.9702015304008 2
# voen -964.5700152635205 3
# voen 1245.7647832563541 3
# voen -1607.6277221105354 4
# voen 1053.2331784159007 4
# voen -1436.5954501500826 5
# voen 1004.0625298758578 5
# voen -1042.0726674743007 6
# voen 1148.0914039379218 6
# voen -1092.0672295563 7
# voen 1100.88863799539 7
# voen -1177.7105813466665 8
# voen 1546.1751170282475 8
# voen -1402.3620232255687 9
# voen 1381.0587278234889 9
# voen -1504.1658148802212 10
# voen 1379.4106226722317 10
# voen -1063.7574712731282 11
# voen 1248.6174761442824 11
# voen -963.3682082002956 12
# voen 1609.0625496085088 12
# voen -1370.6912649485982 13
# voen 1629.6520461370812 13
# voen -1536.292047467595 14
# voen 1779.9429967988274 14
# voen -1326.275011865987 15
# voen 1285.5200715093088 15
# voen -1310.8595144177998 16
# voen 808.8117044728692 16
# voen -1363.5538323482144 18
# voen 809.3708979027963 18
# voen -638.5071347531518 19
# voen 859.2216991676538 19
# voen -1403.9375527998936 20
# voen 853.5088055734946 20
# voen -1292.9594852458938 21
# voen 1350.0339199879506 21
# voen -1036.3141708356322 23
# voen 1260.0079487798405 23
# voen -1417.9554837742794 24
# voen 1596.5561927191973 24
# voen -1515.9030374944564 25
# voen 786.8402132417914 25
# voen -1057.8888599660106 26
# voen 993.1739687972456 26
# voen -1504.1680394189777 28
# voen 827.8890707816784 28
# voen -738.9030714422541 29
# voen 1006.2486953388551 29
# voen -880.0508897472442 30
# voen 1561.305039313563 30
# voen -853.3288960015587 31
# voen 1473.1446219201625 31
# voen -991.3798782900898 33
# voen 1023.9479598879828 33
# voen -1260.2604339287086 35
# voen 845.8705736855431 35
# voen -837.0886508093816 36
# voen 1279.79077194182 36
# voen -1052.5004709629627 38
# voen 1266.923761706603 38
# Used Annotations descriptions: ['OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_Left', 'OVTK_GDF_Right', 'OVTK_GDF_Tongue', 'OVTK_GDF_Up']
# c:\git\BCI_MI_Study\BCIAllFunction.py:92: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   train_data = EEG_epoch[key_subs]['Raw_Epoch'].get_data()
# pipo_HCI -56.039386811524025 79
# pipo_HCI 119.8129077028576 79
# Used Annotations descriptions: ['OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_Left', 'OVTK_GDF_Right', 'OVTK_GDF_Tongue', 'OVTK_GDF_Up']
# c:\git\BCI_MI_Study\BCIAllFunction.py:92: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   train_data = EEG_epoch[key_subs]['Raw_Epoch'].get_data()
# c:\git\BCI_MI_Study\BCIAllFunction.py:92: FutureWarning: The current default of copy=False will change to copy=True in 1.7. Set the value of copy explicitly to avoid this warning
#   train_data = EEG_epoch[key_subs]['Raw_Epoch'].get_data()

# %%
# from PIL import Image
# import requests
# from io import BytesIO
# from IPython.display import display
# # Get the image from the URL
# response = requests.get("https://ars.els-cdn.com/content/image/1-s2.0-S156849461830663X-gr5.jpg")
# img = Image.open(BytesIO(response.content))

# # Display the image
# display(img)

# %% [markdown]
# # 1. Best Frequency band selection

# %% [markdown]
# select 10 frequency bands

# %%
from mne.decoding import CSP
from sklearn.svm import SVC
from sklearn.model_selection import ShuffleSplit,StratifiedKFold ,cross_val_score, cross_val_predict
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from scipy import signal

def butter_bandpass(lowcut,highcut,fs,order):
    nyq = 0.5*fs
    low = lowcut/nyq
    high = highcut/nyq
    b,a = signal.butter(order,[low,high],'bandpass')
    return b,a

def butter_bandpass_filter(data, lowcut = 6, highcut = 30, order = 4):
    b,a = butter_bandpass(lowcut,highcut,250,order)
    y = signal.filtfilt(b,a,data,axis=2)
    return y

def discriminative_frequency_band_selection(data, label_1, label_2):
    Bh, Bl = 32, 6  # Initial upper and lower frequency limits
    A1, A2 = 0, 0  # Initial accuracy values

    # Step 1: Finding Bh
    while A1 >= A2:
        Bh -= 2
        A2 = A1        
        if(Bl >= Bh):
            break
        A1 = train_classifier(Bh, Bl, data, label_1, label_2)  # Design filter and train classifier using CSP


    Bh += 1  # Adjust Bh back
    A1 = train_classifier(Bh, Bl, data, label_1, label_2)

    if A1 >= A2:
        A2 = A1
    else:
        Bh = Bh + 1 
        A1 = A2

    # Step 2: Finding Bl
    while A1 >= A2:
        Bl += 2
        A2 = A1
        if(Bl >= Bh):
            break
        A1 = train_classifier(Bh, Bl, data, label_1, label_2)  # Design filter and train classifier using CSP

    Bl -= 1  # Adjust Bl back
    A1 = train_classifier(Bh, Bl, data, label_1, label_2)

    if A1 >= A2:
        A2 = A1
    else:
        Bh = Bh + 1 
        A1 = A2

    return Bh, Bl, A1


def train_classifier(Bh, Bl, data, label_1, label_2):

    init_data = data["Raw_Epoch"][np.where((data['label'] == label_1) | (data['label'] == label_2))]
    init_label = data['label'][np.where((data['label'] == label_1) | (data['label'] == label_2))]

    # init_data = data["Raw_Epoch"]
    # init_label = data['label']

    filtered_data = butter_bandpass_filter(init_data, lowcut= Bl, highcut= Bh)

    x_train, x_test, y_train, y_test = train_test_split(filtered_data, init_label, test_size=test_size, random_state = SEED, stratify=init_label)

    csp = CSP(n_components = 8, reg=None, log=None, rank= 'info' , cov_est = 'epoch')
    csp.fit(x_train, y_train)

    x_train = csp.transform(x_train)
    x_test = csp.transform(x_test)

    # Initialize SVM with a linear kernel
    clf = SVC()

    param_grid = {
        'C':[0.01, 0.1, 1, 10 ,100],
        'kernel': ['linear', 'rbf', 'poly'],  # Example kernels
    }

    grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='accuracy')

    grid_search.fit(x_train, y_train)
    y_pred = grid_search.predict(x_test)

    return accuracy_score(y_test, y_pred)


indices = [0, 1, 2, 3]
pairs = []
band_high = []
band_low = []
acc= []
class_name = ['left', 'right', 'non', 'feet']

# Nested loop to generate all pairs without reversing and without self-pairing
for i in range(len(indices)):
    for j in range(i + 1, len(indices)):
        pairs.append((indices[i], indices[j]))
        Bh, Bl, A1 = discriminative_frequency_band_selection(EEG_Epochs[target_data], label_1= indices[i], label_2 = indices[j])
        band_high.append(Bh)
        band_low.append(Bl)
        acc.append(A1)

for i in range(len(indices)):
    for j in range(i + 1, len(indices)):
        print(f"The selected frequency band of {class_name[i]} vs {class_name[j]} is: Bl = {band_low[j-1+i]}, Bh = {band_high[j-1+i]}, Acc = {acc[j-1+i]}" )
# Out:
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# ...
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# The selected frequency band of left vs right is: Bl = 7, Bh = 27, Acc = 0.6111111111111112
# The selected frequency band of left vs non is: Bl = 9, Bh = 28, Acc = 0.8888888888888888
# The selected frequency band of left vs feet is: Bl = 9, Bh = 22, Acc = 0.5555555555555556
# The selected frequency band of right vs non is: Bl = 9, Bh = 22, Acc = 0.5555555555555556
# The selected frequency band of right vs feet is: Bl = 13, Bh = 30, Acc = 0.7222222222222222
# The selected frequency band of non vs feet is: Bl = 7, Bh = 27, Acc = 0.4444444444444444

# %%
band_high = [32, 32, 32, 32, 32, 32] 
band_low = [6, 6, 6, 6, 6, 6]

# %%
print(band_low)
print(band_high)
# Out:
# [6, 6, 6, 6, 6, 6]
# [32, 32, 32, 32, 32, 32]

# %%
stack_csp_train = []
stack_csp_test = []
stack_cnn_train = []
stack_cnn_test = []

init_data = EEG_Epochs[target_data]['Raw_Epoch']
init_label = EEG_Epochs[target_data]['label']
x_train, x_test, y_train, y_test = train_test_split(init_data, init_label, test_size=test_size, random_state = SEED, stratify=init_label)

for j in range(0,3):
    stack_csp_train = []
    stack_csp_test = []
    for i in range(0,len(band_high)):

        # init_data = EEG_Epochs['voen']['Raw_Epoch'][0+(500*i):1000+(500*i)]
        # init_label = EEG_Epochs['voen']['label']
        
        filter_x_train = butter_bandpass_filter(x_train[:,:,0+(250*j):500+(250*j)] ,lowcut= band_low[i], highcut=band_high[i])
        filter_x_test = butter_bandpass_filter(x_test[:,:,0+(250*j):500+(250*j)] ,lowcut= band_low[i], highcut=band_high[i])

        # x_train, x_test, y_train, y_test = train_test_split(filtered_data, init_label, test_size=0.3, random_state = 42, stratify=init_label)

        csp = CSP(n_components = 8, reg=None, log=None, rank= 'info', cov_est = 'epoch')
        csp.fit(filter_x_train, y_train)

        filter_x_train = csp.transform(filter_x_train)
        filter_x_test = csp.transform(filter_x_test)

        stack_csp_train.append(filter_x_train)
        stack_csp_test.append(filter_x_test)


    stack_cnn_train.append(np.hstack(np.array(stack_csp_train)))
    stack_cnn_test.append(np.hstack(np.array(stack_csp_test)))
# Out:
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# ...
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank='info'
#     MAG: rank 5 after 0 projectors applied to 5 channels
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.

# %%
train_for_cnn = np.transpose(stack_cnn_train, (1, 2, 0))
test_for_cnn = np.transpose(stack_cnn_test, (1, 2, 0))

# %% [markdown]
# # CNN Model

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import keras
from keras.layers import Dropout
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, classification_report

# Define the number of folds
num_folds = 5

# Prepare KFold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True, random_state=SEED)

# Define lists to store evaluation results across folds
accuracy_per_fold = []
confusion_matrices = []
classification_reports = []

# Variables to keep track of the best model
best_model_weights = None
best_val_accuracy = 0
best_fold_number = -1

num_classes = 4

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# Iterate over each fold
for fold, (train_idx, val_idx) in enumerate(kf.split(train_for_cnn)):
    print(f"Training on fold {fold + 1}/{num_folds}")
    
    # Split the data into training and validation sets for this fold
    x_train_fold, x_val_fold = train_for_cnn[train_idx], train_for_cnn[val_idx]
    y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]
    
    # Define the model architecture
    model = models.Sequential()
    
    # Input layer
    model.add(layers.InputLayer(input_shape=(train_for_cnn.shape[1], 3, 1)))
    
    # Convolutional layers
    model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
    model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
    model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
    model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
    
    # Max Pooling layer
    model.add(layers.MaxPooling2D((2, 2), strides=2))
    
    # Fully Connected (Dense) layer
    model.add(layers.Flatten())
    model.add(layers.Dense(640, activation='relu'))
    model.add(Dropout(0.5))
    model.add(layers.Dense(4, activation='softmax'))  # Output layer for 4 classes
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model.h5', 
                                                monitor='val_accuracy', 
                                                save_best_only=True, 
                                                mode='max', 
                                                verbose=0)
    
    # Train the model
    history = model.fit(x_train_fold, y_train_fold,
                        epochs=100,
                        batch_size=24,
                        validation_data=(x_val_fold, y_val_fold),
                        callbacks=[checkpoint],
                        verbose=1)
    
    best_model_infold = tf.keras.models.load_model('best_model.h5')

    # Evaluate the model on the validation data for this fold
    val_loss, val_acc = best_model_infold.evaluate(x_val_fold, y_val_fold)
    print(f"Fold {fold + 1} - Validation accuracy: {val_acc}")
    
    # Store the accuracy for this fold
    accuracy_per_fold.append(val_acc)
    
    # Check if this fold's model is the best so far
    if val_acc > best_val_accuracy:
        best_val_accuracy = val_acc
        best_fold_number = fold + 1  # Fold number (1-based index)
        best_model_weights = best_model_infold.get_weights()  # Save the weights of the best model


# After all folds are evaluated
print(f"\nBest fold: Fold {best_fold_number} with validation accuracy: {best_val_accuracy}")

# To use the best model's weights later:
final_model = models.Sequential()
# Define the same architecture as the original model
final_model.add(layers.InputLayer(input_shape=(train_for_cnn.shape[1], 3, 1)))
final_model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
final_model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
final_model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
final_model.add(layers.Conv2D(16, (9, 5), activation='relu', padding='same'))
final_model.add(layers.MaxPooling2D((2, 2), strides=2))
final_model.add(layers.Flatten())
final_model.add(layers.Dense(640, activation='relu'))
final_model.add(Dropout(0.5))
final_model.add(layers.Dense(4, activation='softmax'))

# Compile the model
final_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# Load the best weights
final_model.set_weights(best_model_weights)

# You can now evaluate this model on the test data, make predictions, etc.
# Evaluate the best model on the test data
test_loss, test_acc = final_model.evaluate(test_for_cnn, y_test)

print(f"Best model test accuracy: {test_acc}")

# Make predictions with the best model
predictions = final_model.predict(test_for_cnn)

# Convert predictions and true labels from one-hot encoding to class labels
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)
print("Confusion Matrix:")
print(conf_matrix)

# Print a classification report for more detailed metrics
print("Classification Report:")
print(classification_report(true_classes, predicted_classes))
# Out:
# Training on fold 1/5
# Epoch 1/100
# 3/3 [==============================] - 1s 128ms/step - loss: 1.3875 - accuracy: 0.1642 - val_loss: 1.3907 - val_accuracy: 0.1176
# Epoch 2/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3823 - accuracy: 0.2985 - val_loss: 1.3922 - val_accuracy: 0.1176
# Epoch 3/100
# 1/3 [=========>....................] - ETA: 0s - loss: 1.3791 - accuracy: 0.2500
# C:\Users\pipo_\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3794 - accuracy: 0.2985 - val_loss: 1.3963 - val_accuracy: 0.1176
# Epoch 4/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3759 - accuracy: 0.2836 - val_loss: 1.4020 - val_accuracy: 0.1176
# Epoch 5/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.3730 - accuracy: 0.2836 - val_loss: 1.4107 - val_accuracy: 0.1176
# Epoch 6/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3604 - accuracy: 0.2836 - val_loss: 1.4229 - val_accuracy: 0.1176
# Epoch 7/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3555 - accuracy: 0.2985 - val_loss: 1.4305 - val_accuracy: 0.1176
# Epoch 8/100
# 3/3 [==============================] - 0s 43ms/step - loss: 1.3371 - accuracy: 0.2836 - val_loss: 1.4480 - val_accuracy: 0.1176
# Epoch 9/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.3294 - accuracy: 0.3284 - val_loss: 1.4817 - val_accuracy: 0.1176
# Epoch 10/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3012 - accuracy: 0.3582 - val_loss: 1.5165 - val_accuracy: 0.1176
# Epoch 11/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.2902 - accuracy: 0.3284 - val_loss: 1.5572 - val_accuracy: 0.1176
# Epoch 12/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1.2467 - accuracy: 0.4478 - val_loss: 1.6321 - val_accuracy: 0.1765
# Epoch 13/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.2470 - accuracy: 0.4627 - val_loss: 1.6738 - val_accuracy: 0.1176
# Epoch 14/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.1996 - accuracy: 0.4925 - val_loss: 1.7027 - val_accuracy: 0.1765
# Epoch 15/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1938 - accuracy: 0.5224 - val_loss: 1.6397 - val_accuracy: 0.2941
# Epoch 16/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1573 - accuracy: 0.5672 - val_loss: 1.6687 - val_accuracy: 0.1765
# Epoch 17/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.1221 - accuracy: 0.6269 - val_loss: 1.7486 - val_accuracy: 0.1765
# Epoch 18/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.0781 - accuracy: 0.5821 - val_loss: 1.7769 - val_accuracy: 0.2353
# Epoch 19/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.0348 - accuracy: 0.5970 - val_loss: 1.7105 - val_accuracy: 0.2353
# Epoch 20/100
# 3/3 [==============================] - 0s 62ms/step - loss: 1.0141 - accuracy: 0.6269 - val_loss: 1.6921 - val_accuracy: 0.3529
# Epoch 21/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9088 - accuracy: 0.7164 - val_loss: 1.8502 - val_accuracy: 0.3529
# Epoch 22/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.9160 - accuracy: 0.6567 - val_loss: 1.7091 - val_accuracy: 0.2941
# Epoch 23/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.8691 - accuracy: 0.7164 - val_loss: 1.7282 - val_accuracy: 0.2941
# Epoch 24/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7940 - accuracy: 0.7313 - val_loss: 1.7812 - val_accuracy: 0.2941
# Epoch 25/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8190 - accuracy: 0.7015 - val_loss: 1.7729 - val_accuracy: 0.2941
# Epoch 26/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.7650 - accuracy: 0.7015 - val_loss: 1.9175 - val_accuracy: 0.2941
# Epoch 27/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6667 - accuracy: 0.7910 - val_loss: 1.9245 - val_accuracy: 0.2941
# Epoch 28/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6705 - accuracy: 0.7463 - val_loss: 1.8476 - val_accuracy: 0.2941
# Epoch 29/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6432 - accuracy: 0.7612 - val_loss: 1.9315 - val_accuracy: 0.2941
# Epoch 30/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6017 - accuracy: 0.8507 - val_loss: 2.2386 - val_accuracy: 0.2941
# Epoch 31/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5378 - accuracy: 0.8209 - val_loss: 2.0943 - val_accuracy: 0.2941
# Epoch 32/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.5293 - accuracy: 0.8358 - val_loss: 2.0104 - val_accuracy: 0.2941
# Epoch 33/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.4646 - accuracy: 0.8507 - val_loss: 2.3506 - val_accuracy: 0.2941
# Epoch 34/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.4462 - accuracy: 0.8806 - val_loss: 2.3612 - val_accuracy: 0.2941
# Epoch 35/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3869 - accuracy: 0.8806 - val_loss: 2.3790 - val_accuracy: 0.2941
# Epoch 36/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3616 - accuracy: 0.9104 - val_loss: 2.7267 - val_accuracy: 0.2941
# Epoch 37/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.3731 - accuracy: 0.8955 - val_loss: 2.6062 - val_accuracy: 0.2941
# Epoch 38/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2955 - accuracy: 0.9104 - val_loss: 2.6544 - val_accuracy: 0.2941
# Epoch 39/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2901 - accuracy: 0.9403 - val_loss: 3.0622 - val_accuracy: 0.2941
# Epoch 40/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2543 - accuracy: 0.9701 - val_loss: 2.6903 - val_accuracy: 0.2941
# Epoch 41/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2289 - accuracy: 0.9254 - val_loss: 2.8989 - val_accuracy: 0.2941
# Epoch 42/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.1789 - accuracy: 0.9701 - val_loss: 3.2659 - val_accuracy: 0.2941
# Epoch 43/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1733 - accuracy: 0.9701 - val_loss: 3.1817 - val_accuracy: 0.2941
# Epoch 44/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1466 - accuracy: 0.9552 - val_loss: 3.1487 - val_accuracy: 0.2941
# Epoch 45/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1187 - accuracy: 0.9701 - val_loss: 3.5539 - val_accuracy: 0.2941
# Epoch 46/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1278 - accuracy: 0.9851 - val_loss: 3.6547 - val_accuracy: 0.2941
# Epoch 47/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1109 - accuracy: 0.9851 - val_loss: 3.3310 - val_accuracy: 0.2941
# Epoch 48/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0866 - accuracy: 0.9851 - val_loss: 3.4843 - val_accuracy: 0.2941
# Epoch 49/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0853 - accuracy: 0.9851 - val_loss: 3.9693 - val_accuracy: 0.2941
# Epoch 50/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0771 - accuracy: 1.0000 - val_loss: 3.8651 - val_accuracy: 0.2941
# Epoch 51/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0616 - accuracy: 1.0000 - val_loss: 3.6337 - val_accuracy: 0.2941
# Epoch 52/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0642 - accuracy: 1.0000 - val_loss: 3.8754 - val_accuracy: 0.2941
# Epoch 53/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0404 - accuracy: 1.0000 - val_loss: 4.1347 - val_accuracy: 0.2941
# Epoch 54/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 4.2254 - val_accuracy: 0.2941
# Epoch 55/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 4.2991 - val_accuracy: 0.2941
# Epoch 56/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 4.5468 - val_accuracy: 0.2941
# Epoch 57/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 4.5860 - val_accuracy: 0.2941
# Epoch 58/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 4.5008 - val_accuracy: 0.2353
# Epoch 59/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 4.6435 - val_accuracy: 0.2353
# Epoch 60/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 4.8736 - val_accuracy: 0.2941
# Epoch 61/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 4.9799 - val_accuracy: 0.2941
# Epoch 62/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 4.9913 - val_accuracy: 0.2941
# Epoch 63/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 4.8132 - val_accuracy: 0.2941
# Epoch 64/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 4.7673 - val_accuracy: 0.2941
# Epoch 65/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 4.8854 - val_accuracy: 0.2941
# Epoch 66/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 5.1222 - val_accuracy: 0.2941
# Epoch 67/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 5.0239 - val_accuracy: 0.2941
# Epoch 68/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 4.7808 - val_accuracy: 0.2353
# Epoch 69/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 4.7983 - val_accuracy: 0.2353
# Epoch 70/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 5.0483 - val_accuracy: 0.2941
# Epoch 71/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 5.2836 - val_accuracy: 0.2941
# Epoch 72/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 5.3740 - val_accuracy: 0.2941
# Epoch 73/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 5.4085 - val_accuracy: 0.2941
# Epoch 74/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 5.5089 - val_accuracy: 0.2941
# Epoch 75/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 5.5786 - val_accuracy: 0.2353
# Epoch 76/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 5.5911 - val_accuracy: 0.2353
# Epoch 77/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 5.5654 - val_accuracy: 0.2941
# Epoch 78/100
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 5.5254 - val_accuracy: 0.2941
# Epoch 79/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 5.4877 - val_accuracy: 0.2941
# Epoch 80/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 5.5383 - val_accuracy: 0.2941
# Epoch 81/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 5.6668 - val_accuracy: 0.2941
# Epoch 82/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 5.8506 - val_accuracy: 0.2941
# Epoch 83/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 5.9405 - val_accuracy: 0.2941
# Epoch 84/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 5.9249 - val_accuracy: 0.2941
# Epoch 85/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 5.8826 - val_accuracy: 0.2941
# Epoch 86/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 5.8161 - val_accuracy: 0.2941
# Epoch 87/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 5.8788 - val_accuracy: 0.2941
# Epoch 88/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 6.0351 - val_accuracy: 0.2353
# Epoch 89/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 6.0358 - val_accuracy: 0.2941
# Epoch 90/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 5.9949 - val_accuracy: 0.2941
# Epoch 91/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 5.9514 - val_accuracy: 0.2941
# Epoch 92/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 5.9249 - val_accuracy: 0.2941
# Epoch 93/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 5.9214 - val_accuracy: 0.2941
# Epoch 94/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 5.9492 - val_accuracy: 0.2941
# Epoch 95/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 6.0669 - val_accuracy: 0.2941
# Epoch 96/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 6.1804 - val_accuracy: 0.2941
# Epoch 97/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 6.2282 - val_accuracy: 0.2941
# Epoch 98/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 6.2590 - val_accuracy: 0.2941
# Epoch 99/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 6.2807 - val_accuracy: 0.2941
# Epoch 100/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 6.3103 - val_accuracy: 0.2941
# 1/1 [==============================] - 0s 167ms/step - loss: 1.6921 - accuracy: 0.3529
# Fold 1 - Validation accuracy: 0.3529411852359772
# Training on fold 2/5
# Epoch 1/100
# 3/3 [==============================] - 1s 135ms/step - loss: 1.3875 - accuracy: 0.2388 - val_loss: 1.3865 - val_accuracy: 0.1765
# Epoch 2/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3855 - accuracy: 0.2537 - val_loss: 1.3868 - val_accuracy: 0.1765
# Epoch 3/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3828 - accuracy: 0.2985 - val_loss: 1.3882 - val_accuracy: 0.1765
# Epoch 4/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3785 - accuracy: 0.2985 - val_loss: 1.3902 - val_accuracy: 0.1765
# Epoch 5/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3758 - accuracy: 0.2985 - val_loss: 1.3918 - val_accuracy: 0.1765
# Epoch 6/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3691 - accuracy: 0.3134 - val_loss: 1.3944 - val_accuracy: 0.1176
# Epoch 7/100
# 3/3 [==============================] - 0s 63ms/step - loss: 1.3654 - accuracy: 0.2836 - val_loss: 1.3971 - val_accuracy: 0.2353
# Epoch 8/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3563 - accuracy: 0.3582 - val_loss: 1.4017 - val_accuracy: 0.2353
# Epoch 9/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3520 - accuracy: 0.3731 - val_loss: 1.4099 - val_accuracy: 0.2353
# Epoch 10/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3381 - accuracy: 0.3731 - val_loss: 1.4224 - val_accuracy: 0.2353
# Epoch 11/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3185 - accuracy: 0.4030 - val_loss: 1.4381 - val_accuracy: 0.2353
# Epoch 12/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.2973 - accuracy: 0.4328 - val_loss: 1.4487 - val_accuracy: 0.2353
# Epoch 13/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.2749 - accuracy: 0.4030 - val_loss: 1.4729 - val_accuracy: 0.2353
# Epoch 14/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.2774 - accuracy: 0.4627 - val_loss: 1.5031 - val_accuracy: 0.1765
# Epoch 15/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2272 - accuracy: 0.4478 - val_loss: 1.5703 - val_accuracy: 0.2941
# Epoch 16/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2805 - accuracy: 0.4179 - val_loss: 1.5874 - val_accuracy: 0.2941
# Epoch 17/100
# 3/3 [==============================] - 0s 51ms/step - loss: 1.2201 - accuracy: 0.4179 - val_loss: 1.5724 - val_accuracy: 0.4706
# Epoch 18/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1.2466 - accuracy: 0.5224 - val_loss: 1.5388 - val_accuracy: 0.2941
# Epoch 19/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.1685 - accuracy: 0.5970 - val_loss: 1.5714 - val_accuracy: 0.0588
# Epoch 20/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.1580 - accuracy: 0.5821 - val_loss: 1.6046 - val_accuracy: 0.1176
# Epoch 21/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0857 - accuracy: 0.5821 - val_loss: 1.6686 - val_accuracy: 0.1176
# Epoch 22/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.0482 - accuracy: 0.6119 - val_loss: 1.7564 - val_accuracy: 0.2941
# Epoch 23/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.0448 - accuracy: 0.6119 - val_loss: 1.7792 - val_accuracy: 0.3529
# Epoch 24/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9948 - accuracy: 0.5970 - val_loss: 1.8214 - val_accuracy: 0.2941
# Epoch 25/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.9430 - accuracy: 0.6418 - val_loss: 1.8899 - val_accuracy: 0.3529
# Epoch 26/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9314 - accuracy: 0.6119 - val_loss: 1.9758 - val_accuracy: 0.3529
# Epoch 27/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.8699 - accuracy: 0.6418 - val_loss: 1.9126 - val_accuracy: 0.3529
# Epoch 28/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8321 - accuracy: 0.6716 - val_loss: 2.0871 - val_accuracy: 0.3529
# Epoch 29/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7781 - accuracy: 0.7761 - val_loss: 2.1899 - val_accuracy: 0.2353
# Epoch 30/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.7942 - accuracy: 0.6716 - val_loss: 2.2112 - val_accuracy: 0.2353
# Epoch 31/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7088 - accuracy: 0.7313 - val_loss: 2.4007 - val_accuracy: 0.3529
# Epoch 32/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.7532 - accuracy: 0.7164 - val_loss: 2.3080 - val_accuracy: 0.2353
# Epoch 33/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.6560 - accuracy: 0.7463 - val_loss: 2.3219 - val_accuracy: 0.2353
# Epoch 34/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6922 - accuracy: 0.7761 - val_loss: 2.4767 - val_accuracy: 0.2353
# Epoch 35/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6630 - accuracy: 0.7612 - val_loss: 2.4158 - val_accuracy: 0.2353
# Epoch 36/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5860 - accuracy: 0.8507 - val_loss: 2.5397 - val_accuracy: 0.2353
# Epoch 37/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.5135 - accuracy: 0.8358 - val_loss: 2.6278 - val_accuracy: 0.2941
# Epoch 38/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5218 - accuracy: 0.8657 - val_loss: 2.5736 - val_accuracy: 0.2941
# Epoch 39/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4925 - accuracy: 0.8507 - val_loss: 2.7518 - val_accuracy: 0.2353
# Epoch 40/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.4204 - accuracy: 0.9254 - val_loss: 2.9566 - val_accuracy: 0.2941
# Epoch 41/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4263 - accuracy: 0.8955 - val_loss: 2.9785 - val_accuracy: 0.2941
# Epoch 42/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3793 - accuracy: 0.9104 - val_loss: 3.0412 - val_accuracy: 0.2353
# Epoch 43/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3786 - accuracy: 0.9254 - val_loss: 3.1706 - val_accuracy: 0.2353
# Epoch 44/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3058 - accuracy: 0.9701 - val_loss: 3.2818 - val_accuracy: 0.2353
# Epoch 45/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3351 - accuracy: 0.9254 - val_loss: 3.2410 - val_accuracy: 0.2353
# Epoch 46/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2899 - accuracy: 0.8955 - val_loss: 3.3685 - val_accuracy: 0.2941
# Epoch 47/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.2459 - accuracy: 0.9403 - val_loss: 3.5181 - val_accuracy: 0.2941
# Epoch 48/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2426 - accuracy: 0.9254 - val_loss: 3.5704 - val_accuracy: 0.2353
# Epoch 49/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.2045 - accuracy: 0.9701 - val_loss: 3.8786 - val_accuracy: 0.2941
# Epoch 50/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2373 - accuracy: 0.9254 - val_loss: 4.0183 - val_accuracy: 0.2353
# Epoch 51/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1990 - accuracy: 0.9403 - val_loss: 3.6970 - val_accuracy: 0.2941
# Epoch 52/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.2975 - accuracy: 0.8806 - val_loss: 3.7593 - val_accuracy: 0.2941
# Epoch 53/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2183 - accuracy: 0.9403 - val_loss: 4.1181 - val_accuracy: 0.2941
# Epoch 54/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1723 - accuracy: 0.9701 - val_loss: 4.0331 - val_accuracy: 0.2941
# Epoch 55/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.1551 - accuracy: 0.9701 - val_loss: 3.7339 - val_accuracy: 0.3529
# Epoch 56/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.1368 - accuracy: 0.9851 - val_loss: 3.9143 - val_accuracy: 0.3529
# Epoch 57/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0926 - accuracy: 0.9851 - val_loss: 4.2506 - val_accuracy: 0.3529
# Epoch 58/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0819 - accuracy: 1.0000 - val_loss: 4.5480 - val_accuracy: 0.3529
# Epoch 59/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0854 - accuracy: 0.9851 - val_loss: 4.4912 - val_accuracy: 0.2941
# Epoch 60/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0808 - accuracy: 1.0000 - val_loss: 4.7749 - val_accuracy: 0.2941
# Epoch 61/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0716 - accuracy: 0.9851 - val_loss: 5.1834 - val_accuracy: 0.3529
# Epoch 62/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0839 - accuracy: 1.0000 - val_loss: 5.2396 - val_accuracy: 0.2353
# Epoch 63/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0679 - accuracy: 1.0000 - val_loss: 5.1521 - val_accuracy: 0.2941
# Epoch 64/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 5.1711 - val_accuracy: 0.3529
# Epoch 65/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0522 - accuracy: 0.9851 - val_loss: 5.1854 - val_accuracy: 0.3529
# Epoch 66/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 5.3151 - val_accuracy: 0.2941
# Epoch 67/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0416 - accuracy: 1.0000 - val_loss: 5.4226 - val_accuracy: 0.2941
# Epoch 68/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 5.5129 - val_accuracy: 0.3529
# Epoch 69/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 5.5981 - val_accuracy: 0.3529
# Epoch 70/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 5.6663 - val_accuracy: 0.3529
# Epoch 71/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 5.7531 - val_accuracy: 0.2941
# Epoch 72/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 5.8219 - val_accuracy: 0.2941
# Epoch 73/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 5.8312 - val_accuracy: 0.2941
# Epoch 74/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 5.8958 - val_accuracy: 0.2941
# Epoch 75/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 5.9873 - val_accuracy: 0.2941
# Epoch 76/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 6.0775 - val_accuracy: 0.2941
# Epoch 77/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 6.1918 - val_accuracy: 0.3529
# Epoch 78/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 6.1857 - val_accuracy: 0.3529
# Epoch 79/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 6.0708 - val_accuracy: 0.3529
# Epoch 80/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 6.1299 - val_accuracy: 0.3529
# Epoch 81/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 6.2965 - val_accuracy: 0.2941
# Epoch 82/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 6.4587 - val_accuracy: 0.2941
# Epoch 83/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 6.5554 - val_accuracy: 0.2941
# Epoch 84/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 6.3252 - val_accuracy: 0.3529
# Epoch 85/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 6.3892 - val_accuracy: 0.3529
# Epoch 86/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 6.5352 - val_accuracy: 0.2941
# Epoch 87/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 6.4753 - val_accuracy: 0.2941
# Epoch 88/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 6.3411 - val_accuracy: 0.3529
# Epoch 89/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 6.2319 - val_accuracy: 0.3529
# Epoch 90/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 6.2903 - val_accuracy: 0.3529
# Epoch 91/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 6.5072 - val_accuracy: 0.2941
# Epoch 92/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 6.6638 - val_accuracy: 0.2941
# Epoch 93/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 6.6484 - val_accuracy: 0.2941
# Epoch 94/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 6.5290 - val_accuracy: 0.2941
# Epoch 95/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 6.5785 - val_accuracy: 0.2941
# Epoch 96/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 6.6523 - val_accuracy: 0.2941
# Epoch 97/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 6.6964 - val_accuracy: 0.2941
# Epoch 98/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 6.7196 - val_accuracy: 0.2941
# Epoch 99/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 6.7913 - val_accuracy: 0.2941
# Epoch 100/100
# 3/3 [==============================] - 0s 52ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 6.8387 - val_accuracy: 0.2941
# 1/1 [==============================] - 0s 134ms/step - loss: 1.5724 - accuracy: 0.4706
# Fold 2 - Validation accuracy: 0.47058823704719543
# Training on fold 3/5
# Epoch 1/100
# 3/3 [==============================] - 1s 126ms/step - loss: 1.3873 - accuracy: 0.2388 - val_loss: 1.3881 - val_accuracy: 0.1176
# Epoch 2/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.3827 - accuracy: 0.3881 - val_loss: 1.3882 - val_accuracy: 0.1765
# Epoch 3/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3815 - accuracy: 0.3134 - val_loss: 1.3884 - val_accuracy: 0.1765
# Epoch 4/100
# 3/3 [==============================] - 0s 50ms/step - loss: 1.3739 - accuracy: 0.4478 - val_loss: 1.3887 - val_accuracy: 0.2353
# Epoch 5/100
# 3/3 [==============================] - 0s 52ms/step - loss: 1.3694 - accuracy: 0.4627 - val_loss: 1.3876 - val_accuracy: 0.3529
# Epoch 6/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3690 - accuracy: 0.4030 - val_loss: 1.3868 - val_accuracy: 0.3529
# Epoch 7/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3604 - accuracy: 0.4925 - val_loss: 1.3850 - val_accuracy: 0.2941
# Epoch 8/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3496 - accuracy: 0.4627 - val_loss: 1.3809 - val_accuracy: 0.3529
# Epoch 9/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3265 - accuracy: 0.5075 - val_loss: 1.3745 - val_accuracy: 0.3529
# Epoch 10/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3177 - accuracy: 0.4776 - val_loss: 1.3621 - val_accuracy: 0.3529
# Epoch 11/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.2999 - accuracy: 0.3881 - val_loss: 1.3441 - val_accuracy: 0.4706
# Epoch 12/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2423 - accuracy: 0.5373 - val_loss: 1.3193 - val_accuracy: 0.4706
# Epoch 13/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.2150 - accuracy: 0.5224 - val_loss: 1.2872 - val_accuracy: 0.5294
# Epoch 14/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.1906 - accuracy: 0.5970 - val_loss: 1.2836 - val_accuracy: 0.4706
# Epoch 15/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1374 - accuracy: 0.5224 - val_loss: 1.2567 - val_accuracy: 0.3529
# Epoch 16/100
# 3/3 [==============================] - 0s 49ms/step - loss: 1.0880 - accuracy: 0.6418 - val_loss: 1.2118 - val_accuracy: 0.5294
# Epoch 17/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0484 - accuracy: 0.5672 - val_loss: 1.2080 - val_accuracy: 0.4118
# Epoch 18/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.9949 - accuracy: 0.6418 - val_loss: 1.2208 - val_accuracy: 0.4706
# Epoch 19/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.9899 - accuracy: 0.5970 - val_loss: 1.2391 - val_accuracy: 0.5294
# Epoch 20/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.9006 - accuracy: 0.6716 - val_loss: 1.2467 - val_accuracy: 0.5294
# Epoch 21/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8682 - accuracy: 0.6716 - val_loss: 1.2274 - val_accuracy: 0.3529
# Epoch 22/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8493 - accuracy: 0.6567 - val_loss: 1.2675 - val_accuracy: 0.3529
# Epoch 23/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.7789 - accuracy: 0.6716 - val_loss: 1.2921 - val_accuracy: 0.5294
# Epoch 24/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.7175 - accuracy: 0.7313 - val_loss: 1.2906 - val_accuracy: 0.4118
# Epoch 25/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.6867 - accuracy: 0.7015 - val_loss: 1.3141 - val_accuracy: 0.4706
# Epoch 26/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.6117 - accuracy: 0.8209 - val_loss: 1.3551 - val_accuracy: 0.4118
# Epoch 27/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.5218 - accuracy: 0.8507 - val_loss: 1.4637 - val_accuracy: 0.4706
# Epoch 28/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.5298 - accuracy: 0.7910 - val_loss: 1.5074 - val_accuracy: 0.3529
# Epoch 29/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.5080 - accuracy: 0.7910 - val_loss: 1.4733 - val_accuracy: 0.4118
# Epoch 30/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.4480 - accuracy: 0.8358 - val_loss: 1.5473 - val_accuracy: 0.3529
# Epoch 31/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3965 - accuracy: 0.8657 - val_loss: 1.6094 - val_accuracy: 0.4118
# Epoch 32/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3804 - accuracy: 0.9254 - val_loss: 1.7001 - val_accuracy: 0.4118
# Epoch 33/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.3014 - accuracy: 0.9552 - val_loss: 1.7474 - val_accuracy: 0.4118
# Epoch 34/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3110 - accuracy: 0.9552 - val_loss: 1.8224 - val_accuracy: 0.3529
# Epoch 35/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2511 - accuracy: 0.9403 - val_loss: 1.9131 - val_accuracy: 0.3529
# Epoch 36/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1977 - accuracy: 0.9851 - val_loss: 2.0563 - val_accuracy: 0.4118
# Epoch 37/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2013 - accuracy: 1.0000 - val_loss: 2.2150 - val_accuracy: 0.3529
# Epoch 38/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.1561 - accuracy: 1.0000 - val_loss: 2.2526 - val_accuracy: 0.2941
# Epoch 39/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1695 - accuracy: 0.9701 - val_loss: 2.3409 - val_accuracy: 0.4118
# Epoch 40/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1504 - accuracy: 0.9851 - val_loss: 2.4524 - val_accuracy: 0.4118
# Epoch 41/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1136 - accuracy: 0.9851 - val_loss: 2.5390 - val_accuracy: 0.3529
# Epoch 42/100
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0973 - accuracy: 0.9851 - val_loss: 2.5691 - val_accuracy: 0.4118
# Epoch 43/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0898 - accuracy: 0.9701 - val_loss: 2.6354 - val_accuracy: 0.3529
# Epoch 44/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0691 - accuracy: 1.0000 - val_loss: 2.7314 - val_accuracy: 0.3529
# Epoch 45/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 2.7685 - val_accuracy: 0.4118
# Epoch 46/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 2.9242 - val_accuracy: 0.4118
# Epoch 47/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 3.1488 - val_accuracy: 0.4118
# Epoch 48/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 3.3543 - val_accuracy: 0.3529
# Epoch 49/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0467 - accuracy: 1.0000 - val_loss: 3.3515 - val_accuracy: 0.3529
# Epoch 50/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 3.2776 - val_accuracy: 0.4118
# Epoch 51/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 3.2718 - val_accuracy: 0.4118
# Epoch 52/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 3.4177 - val_accuracy: 0.4118
# Epoch 53/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 3.6401 - val_accuracy: 0.4118
# Epoch 54/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 3.7475 - val_accuracy: 0.4118
# Epoch 55/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 3.6992 - val_accuracy: 0.4118
# Epoch 56/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 3.5838 - val_accuracy: 0.4118
# Epoch 57/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 3.5505 - val_accuracy: 0.4118
# Epoch 58/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 3.6195 - val_accuracy: 0.3529
# Epoch 59/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 3.7482 - val_accuracy: 0.3529
# Epoch 60/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 3.8422 - val_accuracy: 0.4118
# Epoch 61/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 3.9093 - val_accuracy: 0.4118
# Epoch 62/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 3.9745 - val_accuracy: 0.4118
# Epoch 63/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 3.9988 - val_accuracy: 0.4118
# Epoch 64/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 4.0123 - val_accuracy: 0.4118
# Epoch 65/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 4.0456 - val_accuracy: 0.4118
# Epoch 66/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 4.1012 - val_accuracy: 0.4118
# Epoch 67/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 4.2131 - val_accuracy: 0.2941
# Epoch 68/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 4.2013 - val_accuracy: 0.3529
# Epoch 69/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 4.2117 - val_accuracy: 0.4118
# Epoch 70/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 4.2683 - val_accuracy: 0.4118
# Epoch 71/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 4.3428 - val_accuracy: 0.4118
# Epoch 72/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 4.4081 - val_accuracy: 0.4118
# Epoch 73/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 4.4490 - val_accuracy: 0.4118
# Epoch 74/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 4.4605 - val_accuracy: 0.3529
# Epoch 75/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 4.4872 - val_accuracy: 0.3529
# Epoch 76/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 4.4669 - val_accuracy: 0.3529
# Epoch 77/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 4.4525 - val_accuracy: 0.4118
# Epoch 78/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 4.4034 - val_accuracy: 0.4118
# Epoch 79/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 4.3475 - val_accuracy: 0.4118
# Epoch 80/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 4.3482 - val_accuracy: 0.4118
# Epoch 81/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 4.3868 - val_accuracy: 0.4118
# Epoch 82/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 4.4483 - val_accuracy: 0.4118
# Epoch 83/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 4.5210 - val_accuracy: 0.4118
# Epoch 84/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 4.5652 - val_accuracy: 0.4118
# Epoch 85/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 4.6111 - val_accuracy: 0.4118
# Epoch 86/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 4.6700 - val_accuracy: 0.4118
# Epoch 87/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 4.7513 - val_accuracy: 0.4118
# Epoch 88/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 4.8111 - val_accuracy: 0.4118
# Epoch 89/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 4.8290 - val_accuracy: 0.4118
# Epoch 90/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 4.8468 - val_accuracy: 0.4118
# Epoch 91/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 4.8683 - val_accuracy: 0.4118
# Epoch 92/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 4.8969 - val_accuracy: 0.4118
# Epoch 93/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 4.9774 - val_accuracy: 0.4118
# Epoch 94/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 5.0329 - val_accuracy: 0.4118
# Epoch 95/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 5.0422 - val_accuracy: 0.4118
# Epoch 96/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 4.9934 - val_accuracy: 0.4118
# Epoch 97/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 4.9744 - val_accuracy: 0.4118
# Epoch 98/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 4.9716 - val_accuracy: 0.4118
# Epoch 99/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.9855 - val_accuracy: 0.4118
# Epoch 100/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 5.0042 - val_accuracy: 0.4118
# 1/1 [==============================] - 0s 139ms/step - loss: 1.2872 - accuracy: 0.5294
# Fold 3 - Validation accuracy: 0.529411792755127
# Training on fold 4/5
# Epoch 1/100
# 3/3 [==============================] - 1s 125ms/step - loss: 1.3878 - accuracy: 0.1791 - val_loss: 1.3891 - val_accuracy: 0.2353
# Epoch 2/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3830 - accuracy: 0.3284 - val_loss: 1.3918 - val_accuracy: 0.1765
# Epoch 3/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3793 - accuracy: 0.4179 - val_loss: 1.3946 - val_accuracy: 0.1176
# Epoch 4/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3749 - accuracy: 0.3731 - val_loss: 1.3999 - val_accuracy: 0.1765
# Epoch 5/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3668 - accuracy: 0.3582 - val_loss: 1.4066 - val_accuracy: 0.1765
# Epoch 6/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3575 - accuracy: 0.4179 - val_loss: 1.4195 - val_accuracy: 0.1176
# Epoch 7/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.3402 - accuracy: 0.4328 - val_loss: 1.4334 - val_accuracy: 0.1176
# Epoch 8/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3132 - accuracy: 0.4925 - val_loss: 1.4589 - val_accuracy: 0.1765
# Epoch 9/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.2934 - accuracy: 0.4328 - val_loss: 1.4902 - val_accuracy: 0.1765
# Epoch 10/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.2725 - accuracy: 0.5075 - val_loss: 1.5146 - val_accuracy: 0.1765
# Epoch 11/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.2260 - accuracy: 0.5224 - val_loss: 1.5565 - val_accuracy: 0.1176
# Epoch 12/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.1922 - accuracy: 0.4925 - val_loss: 1.5852 - val_accuracy: 0.1765
# Epoch 13/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1420 - accuracy: 0.5672 - val_loss: 1.5858 - val_accuracy: 0.1765
# Epoch 14/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0737 - accuracy: 0.5373 - val_loss: 1.6857 - val_accuracy: 0.1765
# Epoch 15/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.9927 - accuracy: 0.6119 - val_loss: 1.8486 - val_accuracy: 0.1765
# Epoch 16/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.9844 - accuracy: 0.5821 - val_loss: 1.8929 - val_accuracy: 0.1765
# Epoch 17/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9609 - accuracy: 0.5970 - val_loss: 1.8980 - val_accuracy: 0.2353
# Epoch 18/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.8718 - accuracy: 0.6567 - val_loss: 1.9863 - val_accuracy: 0.1765
# Epoch 19/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.8171 - accuracy: 0.6567 - val_loss: 2.1164 - val_accuracy: 0.1765
# Epoch 20/100
# 3/3 [==============================] - 0s 59ms/step - loss: 0.8127 - accuracy: 0.6716 - val_loss: 2.0604 - val_accuracy: 0.2941
# Epoch 21/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7806 - accuracy: 0.7164 - val_loss: 2.2134 - val_accuracy: 0.1765
# Epoch 22/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.7701 - accuracy: 0.7015 - val_loss: 2.1519 - val_accuracy: 0.1765
# Epoch 23/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.7301 - accuracy: 0.7313 - val_loss: 2.1050 - val_accuracy: 0.2353
# Epoch 24/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.6857 - accuracy: 0.7761 - val_loss: 2.1548 - val_accuracy: 0.1765
# Epoch 25/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.6343 - accuracy: 0.7463 - val_loss: 2.3406 - val_accuracy: 0.1765
# Epoch 26/100
# 3/3 [==============================] - 0s 45ms/step - loss: 0.6640 - accuracy: 0.7612 - val_loss: 2.2887 - val_accuracy: 0.1765
# Epoch 27/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.5663 - accuracy: 0.8209 - val_loss: 2.2891 - val_accuracy: 0.1765
# Epoch 28/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5978 - accuracy: 0.7761 - val_loss: 2.3354 - val_accuracy: 0.1765
# Epoch 29/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.5318 - accuracy: 0.7761 - val_loss: 2.5521 - val_accuracy: 0.1765
# Epoch 30/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4877 - accuracy: 0.8507 - val_loss: 2.6017 - val_accuracy: 0.1765
# Epoch 31/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4219 - accuracy: 0.8507 - val_loss: 2.7095 - val_accuracy: 0.1765
# Epoch 32/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4068 - accuracy: 0.8358 - val_loss: 2.8557 - val_accuracy: 0.1765
# Epoch 33/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3710 - accuracy: 0.8507 - val_loss: 3.0056 - val_accuracy: 0.1765
# Epoch 34/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3439 - accuracy: 0.8657 - val_loss: 3.1855 - val_accuracy: 0.1765
# Epoch 35/100
# ...
# Epoch 95/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 7.6646 - val_accuracy: 0.2353
# Epoch 96/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 7.8068 - val_accuracy: 0.2353
# Epoch 97/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 7.9281 - val_accuracy: 0.2353
# Epoch 98/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 7.9741 - val_accuracy: 0.2353
# Epoch 99/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 7.9740 - val_accuracy: 0.2353
# Epoch 100/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 8.0367 - val_accuracy: 0.2353
# 1/1 [==============================] - 0s 130ms/step - loss: 2.0604 - accuracy: 0.2941
# Fold 4 - Validation accuracy: 0.29411765933036804
# Training on fold 5/5
# Epoch 1/100
# 3/3 [==============================] - 1s 122ms/step - loss: 1.3888 - accuracy: 0.1324 - val_loss: 1.3844 - val_accuracy: 0.3125
# Epoch 2/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3852 - accuracy: 0.2500 - val_loss: 1.3873 - val_accuracy: 0.1250
# Epoch 3/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3826 - accuracy: 0.3676 - val_loss: 1.3892 - val_accuracy: 0.1250
# Epoch 4/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3792 - accuracy: 0.3235 - val_loss: 1.3915 - val_accuracy: 0.2500
# Epoch 5/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.3761 - accuracy: 0.3676 - val_loss: 1.3945 - val_accuracy: 0.1875
# Epoch 6/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3695 - accuracy: 0.3676 - val_loss: 1.3979 - val_accuracy: 0.1250
# Epoch 7/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3626 - accuracy: 0.3382 - val_loss: 1.3999 - val_accuracy: 0.1250
# Epoch 8/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3591 - accuracy: 0.2647 - val_loss: 1.4056 - val_accuracy: 0.1250
# Epoch 9/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3416 - accuracy: 0.3971 - val_loss: 1.4084 - val_accuracy: 0.1250
# Epoch 10/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3297 - accuracy: 0.3235 - val_loss: 1.3969 - val_accuracy: 0.3125
# Epoch 11/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.3122 - accuracy: 0.4559 - val_loss: 1.3909 - val_accuracy: 0.2500
# Epoch 12/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2990 - accuracy: 0.4118 - val_loss: 1.3635 - val_accuracy: 0.3125
# Epoch 13/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.2573 - accuracy: 0.6176 - val_loss: 1.3658 - val_accuracy: 0.3125
# Epoch 14/100
# 3/3 [==============================] - 0s 65ms/step - loss: 1.2154 - accuracy: 0.5147 - val_loss: 1.3759 - val_accuracy: 0.3750
# Epoch 15/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.1768 - accuracy: 0.5882 - val_loss: 1.4304 - val_accuracy: 0.3750
# Epoch 16/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.1244 - accuracy: 0.5588 - val_loss: 1.4340 - val_accuracy: 0.3750
# Epoch 17/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.0337 - accuracy: 0.6176 - val_loss: 1.4841 - val_accuracy: 0.2500
# Epoch 18/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.9796 - accuracy: 0.5588 - val_loss: 1.5909 - val_accuracy: 0.4375
# Epoch 19/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.9537 - accuracy: 0.6324 - val_loss: 1.6882 - val_accuracy: 0.4375
# Epoch 20/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.8648 - accuracy: 0.5882 - val_loss: 1.7869 - val_accuracy: 0.2500
# Epoch 21/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.8423 - accuracy: 0.5735 - val_loss: 1.8903 - val_accuracy: 0.2500
# Epoch 22/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.7336 - accuracy: 0.6324 - val_loss: 1.9540 - val_accuracy: 0.3750
# Epoch 23/100
# 3/3 [==============================] - 0s 50ms/step - loss: 0.7691 - accuracy: 0.7206 - val_loss: 2.0505 - val_accuracy: 0.3125
# Epoch 24/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6598 - accuracy: 0.6765 - val_loss: 2.1077 - val_accuracy: 0.2500
# Epoch 25/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.6776 - accuracy: 0.7353 - val_loss: 2.1919 - val_accuracy: 0.3125
# Epoch 26/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.6594 - accuracy: 0.7206 - val_loss: 2.4324 - val_accuracy: 0.2500
# Epoch 27/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.6664 - accuracy: 0.7206 - val_loss: 2.3118 - val_accuracy: 0.2500
# Epoch 28/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5814 - accuracy: 0.7647 - val_loss: 2.3136 - val_accuracy: 0.2500
# Epoch 29/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5152 - accuracy: 0.8235 - val_loss: 2.5225 - val_accuracy: 0.3750
# Epoch 30/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.5651 - accuracy: 0.8088 - val_loss: 2.6785 - val_accuracy: 0.3750
# Epoch 31/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4315 - accuracy: 0.8824 - val_loss: 2.6064 - val_accuracy: 0.2500
# Epoch 32/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.4387 - accuracy: 0.8382 - val_loss: 2.6151 - val_accuracy: 0.2500
# Epoch 33/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.3660 - accuracy: 0.8529 - val_loss: 2.8995 - val_accuracy: 0.2500
# Epoch 34/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3429 - accuracy: 0.9118 - val_loss: 3.1673 - val_accuracy: 0.2500
# Epoch 35/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3119 - accuracy: 0.9118 - val_loss: 3.2461 - val_accuracy: 0.3125
# Epoch 36/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.3308 - accuracy: 0.9118 - val_loss: 3.1547 - val_accuracy: 0.2500
# Epoch 37/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.3297 - accuracy: 0.8971 - val_loss: 3.2089 - val_accuracy: 0.2500
# Epoch 38/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.3561 - accuracy: 0.8971 - val_loss: 3.5893 - val_accuracy: 0.1875
# Epoch 39/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.3102 - accuracy: 0.9118 - val_loss: 3.5746 - val_accuracy: 0.3125
# Epoch 40/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2285 - accuracy: 0.9412 - val_loss: 3.4998 - val_accuracy: 0.3125
# Epoch 41/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2312 - accuracy: 0.9265 - val_loss: 3.5439 - val_accuracy: 0.2500
# Epoch 42/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2119 - accuracy: 0.9265 - val_loss: 3.7593 - val_accuracy: 0.1875
# Epoch 43/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1827 - accuracy: 0.9559 - val_loss: 4.1754 - val_accuracy: 0.2500
# Epoch 44/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.2147 - accuracy: 0.9265 - val_loss: 4.1274 - val_accuracy: 0.2500
# Epoch 45/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1480 - accuracy: 0.9706 - val_loss: 3.9631 - val_accuracy: 0.1875
# Epoch 46/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.1934 - accuracy: 0.9118 - val_loss: 4.1668 - val_accuracy: 0.2500
# Epoch 47/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0990 - accuracy: 1.0000 - val_loss: 4.6803 - val_accuracy: 0.2500
# Epoch 48/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.1586 - accuracy: 0.9853 - val_loss: 4.6918 - val_accuracy: 0.3125
# Epoch 49/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.1034 - accuracy: 0.9853 - val_loss: 4.7442 - val_accuracy: 0.3125
# Epoch 50/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.1155 - accuracy: 0.9559 - val_loss: 4.7467 - val_accuracy: 0.3125
# Epoch 51/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0778 - accuracy: 0.9853 - val_loss: 4.8745 - val_accuracy: 0.2500
# Epoch 52/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.1063 - accuracy: 0.9559 - val_loss: 5.0333 - val_accuracy: 0.2500
# Epoch 53/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0821 - accuracy: 1.0000 - val_loss: 5.0877 - val_accuracy: 0.2500
# Epoch 54/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.1073 - accuracy: 0.9853 - val_loss: 5.0072 - val_accuracy: 0.2500
# Epoch 55/100
# 3/3 [==============================] - 0s 193ms/step - loss: 0.0619 - accuracy: 1.0000 - val_loss: 5.1652 - val_accuracy: 0.2500
# Epoch 56/100
# 3/3 [==============================] - 0s 38ms/step - loss: 0.0749 - accuracy: 0.9706 - val_loss: 5.2912 - val_accuracy: 0.1875
# Epoch 57/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0469 - accuracy: 0.9853 - val_loss: 5.4591 - val_accuracy: 0.2500
# Epoch 58/100
# 3/3 [==============================] - 0s 36ms/step - loss: 0.0536 - accuracy: 1.0000 - val_loss: 5.6034 - val_accuracy: 0.2500
# Epoch 59/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0746 - accuracy: 0.9706 - val_loss: 5.6137 - val_accuracy: 0.2500
# Epoch 60/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 5.7166 - val_accuracy: 0.2500
# Epoch 61/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0550 - accuracy: 0.9706 - val_loss: 5.7436 - val_accuracy: 0.2500
# Epoch 62/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0538 - accuracy: 0.9853 - val_loss: 5.8172 - val_accuracy: 0.2500
# Epoch 63/100
# 3/3 [==============================] - 0s 44ms/step - loss: 0.0597 - accuracy: 0.9853 - val_loss: 5.7105 - val_accuracy: 0.2500
# Epoch 64/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 5.5604 - val_accuracy: 0.1875
# Epoch 65/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0540 - accuracy: 0.9853 - val_loss: 5.6995 - val_accuracy: 0.1875
# Epoch 66/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 5.9047 - val_accuracy: 0.1875
# Epoch 67/100
# 3/3 [==============================] - 0s 43ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 6.1267 - val_accuracy: 0.1875
# Epoch 68/100
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 6.3267 - val_accuracy: 0.2500
# Epoch 69/100
# 3/3 [==============================] - 0s 39ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 6.4220 - val_accuracy: 0.2500
# Epoch 70/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 6.4748 - val_accuracy: 0.1875
# Epoch 71/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 6.4130 - val_accuracy: 0.1875
# Epoch 72/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0295 - accuracy: 1.0000 - val_loss: 6.3631 - val_accuracy: 0.1875
# Epoch 73/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.0399 - accuracy: 1.0000 - val_loss: 6.4186 - val_accuracy: 0.1875
# Epoch 74/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 6.5882 - val_accuracy: 0.1875
# Epoch 75/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 6.7331 - val_accuracy: 0.2500
# Epoch 76/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 6.8164 - val_accuracy: 0.2500
# Epoch 77/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 6.7561 - val_accuracy: 0.2500
# Epoch 78/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 6.6855 - val_accuracy: 0.2500
# Epoch 79/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 6.6848 - val_accuracy: 0.2500
# Epoch 80/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 6.7632 - val_accuracy: 0.2500
# Epoch 81/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 6.8951 - val_accuracy: 0.2500
# Epoch 82/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 7.0237 - val_accuracy: 0.2500
# Epoch 83/100
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 7.1176 - val_accuracy: 0.2500
# Epoch 84/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 7.2008 - val_accuracy: 0.2500
# Epoch 85/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 7.2628 - val_accuracy: 0.2500
# Epoch 86/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0218 - accuracy: 0.9853 - val_loss: 7.1902 - val_accuracy: 0.1875
# Epoch 87/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 7.0257 - val_accuracy: 0.1875
# Epoch 88/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 7.0756 - val_accuracy: 0.1875
# Epoch 89/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 7.2045 - val_accuracy: 0.1875
# Epoch 90/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 7.3415 - val_accuracy: 0.2500
# Epoch 91/100
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 7.4666 - val_accuracy: 0.2500
# Epoch 92/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 7.5464 - val_accuracy: 0.2500
# Epoch 93/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 7.5771 - val_accuracy: 0.2500
# Epoch 94/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 7.5820 - val_accuracy: 0.2500
# Epoch 95/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 7.5506 - val_accuracy: 0.1875
# Epoch 96/100
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 7.5425 - val_accuracy: 0.2500
# Epoch 97/100
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 7.5665 - val_accuracy: 0.2500
# Epoch 98/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 7.5031 - val_accuracy: 0.2500
# Epoch 99/100
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 7.4660 - val_accuracy: 0.2500
# Epoch 100/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 7.4911 - val_accuracy: 0.2500
# 1/1 [==============================] - 0s 139ms/step - loss: 1.5909 - accuracy: 0.4375
# Fold 5 - Validation accuracy: 0.4375
#
# Best fold: Fold 3 with validation accuracy: 0.529411792755127
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3241 - accuracy: 0.3611
# Best model test accuracy: 0.3611111044883728
# 2/2 [==============================] - 0s 3ms/step
# Confusion Matrix:
# [[3 4 2 0]
#  [0 3 5 1]
#  [0 0 7 2]
#  [5 2 2 0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.38      0.33      0.35         9
#            1       0.33      0.33      0.33         9
#            2       0.44      0.78      0.56         9
#            3       0.00      0.00      0.00         9
#
#     accuracy                           0.36        36
#    macro avg       0.29      0.36      0.31        36
# weighted avg       0.29      0.36      0.31        36
