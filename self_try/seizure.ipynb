# %%
import mne

raw_edf_normal = mne.io.read_raw_edf("C:\\Users\\pipo_\\Downloads\\chb01_01.edf",preload = False)
raw_edf_seizure = mne.io.read_raw_edf("C:\\Users\\pipo_\\Downloads\\chb01_03.edf",preload = False)
# Out:
# Extracting EDF parameters from C:\Users\pipo_\Downloads\chb01_01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from C:\Users\pipo_\Downloads\chb01_03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_7336\1543972905.py:9: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw_edf_normal = mne.io.read_raw_edf("C:\\Users\\pipo_\\Downloads\\chb01_01.edf",preload = False)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_7336\1543972905.py:10: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw_edf_seizure = mne.io.read_raw_edf("C:\\Users\\pipo_\\Downloads\\chb01_03.edf",preload = False)

# %% [markdown]
# Before Seizures

# %%
raw_edf_seizure.plot(start=1000, duration=40)
print('...')
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# ...

# %% [markdown]
# Seizures interval: From chb01/chb01-summary.txt
# - File Name: chb01_03.edf
# - File Start Time: 13:43:04
# - File End Time: 14:43:04
# - Number of Seizures in File: 1
# - Seizure Start Time: 2996 seconds
# - Seizure End Time: 3036 seconds

# %%
raw_edf_seizure.plot(start=2996, duration=40)
print('...')
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# ...
